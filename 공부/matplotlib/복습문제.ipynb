# %% [markdown]
# # 1. 기본설정
# - 쓰는 패키지
# - 폰트 설정
# - 폰트 크기 설정
# - -도 나오게 하는 설정

# %% [markdown]
# 답
# import matplotlib
# 폰트-> matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# #matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
# 크기-> matplotlib.rcParams['font.size'] = 15
# 마이너스-> matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 2-1. 기본 그래프
# x=[1,2,3], y=[2,4,8]
# 다음 조건으로 기본 그래프 그리기
# - 그래프 크기는 위 데이터를 근거로, 해상도는 150, 배경색은 검정
# - 제목은 'basic graph', 글자 크기는 20
# - x값을 x에 y값을 y에
# - 선의 두께는 5, 선종류는 점선, 선색깔은 핑크, 점종류는 원, 점크기는 20, 점바깥색은 초록, 점안색은 노랑, 투명도는 0.2
# - (선 없이 점만 나타내는 방법은?)
# - (간략어는)
# - x축의 이름은 'x축', 색은 빨강, 위치는 오른쪽, 크기는 100
# - y축의 이름은 'y축', 색은 파랑, 위치는 위, 크기는 70
# - x축 표시는 1,2,3만 나오게, 60도 회전
# - y축 표시는 3,6,9,12 만 나오게, 60도 회전
# - 범례의 이름은 '데이터', 위치는 왼쪽위(두가지 방법)
# - y값을 각 점 위에 표시-중심,파랑,크기=20
# - 그래프만 보이게 하는 함수

# %% [markdown]
# ### 그림 저장하는 방법은?

# %% [markdown]
# # 2-2. 기본 그래프에서 여러 데이터
# 판다스폴더에 있는 score.xlsx데이터 사용
# - x에는 지원번호(인덱스), y에는 국어, 영어, 수학 3개 따로따로
# - 점 종류다르게, 선의 색 다르게, 선 종류 다르게
# - 범례 왼쪽 위->가로로 3개 되게
# - x축에는 이름이 나타나며 90도 회전
# - 격자무늬: y축만, 색은 보라, 투명도는 0.5, 선스타일은 점선, 선투께는 2
# # 2-3. 수직선긋기(대부분의 plot에 사용가능)
# - 가로긋기: 위치, 범위 지정해서, 색 핑크, 선종류 점선
# - 세로 긋기: 위와 똑같이

# %% [markdown]
# # 3-1. 막대그래프
# labels = ['강백호', '서태웅', '정대만']
# values = [190, 187, 184]
# 위 데이터와 밑의 조건으로 막대그래프 그리기
# - 색은 빨,초,파, 투명도는 0.5, 선두께는 0.5
# - 잘 보이게 y범위 조정
# - x축,y축 데이터 표시 45도로->이름을 강선수,서선수,정선로 표기
# - 각 막대 위에 키 값 표시, 중앙, 색은 파랑, 크기=20
# - 막대안에 선 긋기
# ---
# - 위에서 했던것을 가로로

# %% [markdown]
# # 3-2. 막대그래프 심화:누적, 다중
# ### 누적
# - x에 df의 이름, y는 밑에서부터 국어,영어,수학
# - 이름표시는 60도 회전
# - 범례표시
# ---
# - 위의 꺼를 가로로
# ### 다중
# - x, y에 국어-영어-수학 나란히 중복되지 않게
# - 범례표시
# - x에는 이름이 나오게->60도 회전

# %% [markdown]
# # 4. 원그래프
# values = [30, 25, 20, 13, 10, 2]
# labels = ['Python', 'Java', 'Javascript', 'C#', 'C/C++', 'ETC']
# - 위 데이터로 원그래프
# - 원 끝에 이름이 나오게,색 각각 지정, 소수점 첫째자리 까지 %표시, 시계방향, 시작각도 90도
# - 경계선에 0.05만크 띄기
# - 범례 원 밖에, 범례안에 제목='언어별 선호도'
# ### 심화
# - df의 학교 비율 나타내기:원 끝에 이름이 나오게, 시계방향, 시작각도 90도
# - 소수점 둘째자리 까지 %표시+50% 이상만 표시되게
# - 도넛 모양으로 만들고 도넛 두께는 0.6, 경계선은 흰색으로 구분되게
# - 제목은 '소속학교'

# %% [markdown]
# # 5. 산점도 그래프
# df에 df['학년'] = [3, 3, 2, 1, 1, 3, 2, 2] 추가
# - x에 영어점수, y에 수학점수
# - 각 점은 학년 크기에 비례(*500), 색도 학년에 따라, 색종류는 'viridis', 투명도는 0.3, 마커사용
# - x축은 '영어점수', y축은 '수학점수'
# - 그래프 밖에 색 정보 표시: 1,2,3만 나오게, '학년', 0.5비율, 수평으로
# - 각 포인터에 학년 레이블 표시

# %% [markdown]
# # 6. 히스토그램
# - 범위 정해서 균등분포 난수 100개 뽑기
# - 히스토그램으로 표현: 막대 20개, 색은 빨간색, x범위 지정, 수평으로or 수직으로
# - 각기 다른 평균을 갖는 정규분포난수 100개를 3종류 뽑기
# - 그냥 중첩해서 3개뽑기->옆으로 여러 막대로해서 겹치지 않게->스택으로 위로 쌓기-> 하나의 샘플로 누적쌓기

# %% [markdown]
# # 7. 박스플롯
# - df의 키로 박스플롯 만들고 이상치 확인하고 이상치 지우는 척 하기
# - df의 국어, 수학, 영어를 한 박스플롯 안에, 색=빨/파/초, x축에 이름넣기

# %% [markdown]
# # 6-1. 여러 그래프 동시에
# - 가로 2개, 세로 2개 총 4개 그래프가 들어갈 수 있는 큰 틀 만들기
# - 전체 크기는 15,10이며 전체 제목은 '여러그래프 넣기'
# - 첫번째 그래프에 막대그래프(이름,국어):제목='1번', x축='이름',y축='점수', x값60도회전, 범례, 내부색=노랑, 격자
# - 2번째에 기본그래프(이름~수학,영어): 범례
# - 4번째에 고등학교 종류 원그래프
# # 6-2. 한 plot에 다른 종류 2개
# - 막대그래프로 df의 국어점수
# - 선형으로 df키-> 막대그래프 보다 확실히 위에 오게
