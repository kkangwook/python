# %% [markdown]
# # 3.범례(legend)
# 범례 이름과 위치 설정방법

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
x = [1, 2, 3]
y = [2, 4, 8]

# %%
plt.plot(x, y, label='무슨 데이터') #label=범례 내용
plt.legend(loc='upper right') #범례 출력하는 함수, 위치는 upper|center|lower + left|center|right 가능
#구글에 matplotlib legend치면 가능한 loc나옴->이때 best 옵션은 제일 빈공간에 생성

# %%
plt.plot(x, y, label='범례')
plt.legend(loc=(0.7, 0.8)) # x축, y축 튜플로(0~1 사이)
